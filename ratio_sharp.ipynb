# %% [markdown]
# # Calculo del Ratio de Sharpe

# %%
import pandas as pd
import numpy as np
import time, datetime
import csv
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
twentythree_years_in_seconds = 725328000
now = time.time()
year_ago = now - twentythree_years_in_seconds
end_date = datetime.datetime.fromtimestamp(now)
start_date = datetime.datetime.fromtimestamp(year_ago)

# %%
f = open('symbols.json')
symbols = json.load(f)

# %%
rf_rate = 0.05 # Tasa libre de riesgo
symbols_ratio = []

# %%
risk_free_rate = 0.01
def sharpe_ratio(df):
  print(df.isna().sum())
  df['daily_return'] = df['Adj Close'].pct_change()
  annual_return = np.mean(df["daily_return"]) * 365
  annual_std = np.std(df["daily_return"]) * np.sqrt(365)
  sharpe_ratio = (annual_return - risk_free_rate) / annual_std
  return sharpe_ratio

# %%
for sym in symbols["symbols"]:
  df = pdr.get_data_yahoo(sym, start=start_date, end=end_date)
  ratio = sharpe_ratio(df)
  item = [sym, ratio]
  symbols_ratio.append(item)
  print(f'Ratio Sharpe de {sym}:', ratio)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de MMM: 0.4192171299121675
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AOS: 0.728366755725936
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ABT: 0.610631153380958
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ABBV: 0.9720810638355456
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ACN: 0.7458932151098515
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ATVI: 0.8174695642472207
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ADM: 0.6053923639099448
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ADBE: 0.565618105776521
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ADP: 0.5753996525192046
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AAP: 0.5557978370059732
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AES: 0.2718762542197833
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AFL: 0.5082314516762451
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de A: 0.323879630435993
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de APD: 0.6739708930789786
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AKAM: 0.323363887420004
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ALK: 0.46408179591736576
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ALB: 0.6851537686905191
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ARE: 0.5267489596937751
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ALGN: 0.607418089670505
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ALLE: 0.5444978130514518
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de LNT: 0.6155020917773915
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ALL: 0.5059867013166454
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GOOGL: 0.9331580448651982
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GOOG: 0.934343387044552
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de MO: 0.8463658805471058
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AMZN: 0.6383993338303948
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AMCR: 0.44092648942889195
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AMD: 0.4553092597521598
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AEE: 0.585213375180799
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AAL: 0.3575978887871464
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AEP: 0.5611818651917323
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AXP: 0.42121246740479007
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AIG: 0.0514783387055601
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AMT: 0.4455538918213677
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AWK: 0.8942623806298532
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AMP: 0.6338950795524934
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ABC: 0.8791206877959535
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AME: 0.8952051020297421
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AMGN: 0.44672484565224674
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de APH: 0.6925874333799948
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ADI: 0.3965857110084042
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ANSS: 0.8798200003425104
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AON: 0.6342298991647901
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de APA: 0.36393252223352074
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AAPL: 0.900885591857037
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AMAT: 0.3941494892855066
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de APTV: 0.7481436241232967
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ACGL: 0.8389418735435132
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ANET: 1.0213981617910144
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AJG: 0.7643630097730607
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AIZ: 0.5371591572118714
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de T: 0.32097612580883444
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ATO: 0.7543298753527615
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ADSK: 0.6000179554630649
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AZO: 0.9763393772874998
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AVB: 0.5631011069422401
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AVY: 0.4413035234100938
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BKR: 0.30717130620381955
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BALL: 0.7852987393141054
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BAC: 0.31981856822798715
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BBWI: 0.46150945592029724
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BAX: 0.3827257512762091
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BDX: 0.6809464567399036
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WRB: 0.8723413711953772
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BBY: 0.3928953617560723
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BIO: 0.7488123880938852
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TECH: 0.5488838186434367
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BIIB: 0.505196485338899
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BLK: 0.7758394267194724
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BK: 0.2629114194850918
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BA: 0.5074847379459321
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BKNG: 0.5135813221103775
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BWA: 0.563158798459182
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BXP: 0.40921908436417276
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BSX: 0.41943248214558576
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BMY: 0.3246436806298841
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de AVGO: 1.183145584732412
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BR: 0.7644148225319263
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BRO: 0.8095364290521372
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BG: 0.5418489079536306
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CHRW: 0.6382705926150188
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CDNS: 0.5402364093642728
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CZR: 0.8899723019706932
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CPT: 0.563093668445767
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CPB: 0.3858966394760886
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de COF: 0.3676463152730123
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CAH: 0.4288492007585544
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de KMX: 0.649070923475588
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CCL: 0.20606196040696742
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CARR: 1.5035184901053122
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CTLT: 0.643014045980624
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CAT: 0.6512491833277264
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CBOE: 0.6894299046225119
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CBRE: 0.5856567897799775
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CDW: 1.190247782303419
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CE: 0.5720301639186973
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CNC: 0.7478202467844814
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CNP: 0.40305161868284756
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CDAY: 0.6728659910643588
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CF: 0.7638088951728546
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CRL: 0.5178742646621143
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de SCHW: 0.31161003365253
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CHTR: 0.8688318531051811
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CVX: 0.5303777228473281
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CMG: 0.8622887065358114
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CB: 0.6023014665468963
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CHD: 0.9309765006766137
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CI: 0.5461941005562159
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CINF: 0.48985596634202666
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CTAS: 0.6296779620682977
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CSCO: 0.19809081723504468
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de C: 0.07286963786341444
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CFG: 0.41308650375621186
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CLX: 0.5861762055083674
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CME: 0.8198914873966726
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CMS: 0.4954717383282274
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de KO: 0.47954140282000246
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CTSH: 0.6508117586423982
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CL: 0.43567016282411425
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CMCSA: 0.3712529247107006
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CMA: 0.3132164899905038
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CAG: 0.49203458772963965
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de COP: 0.558251791449026
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ED: 0.6760372125203933
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de STZ: 0.7720654190230846
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CEG: 1.6092989766365635
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de COO: 0.6677847284093564
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CPRT: 0.7838382419386895
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GLW: 0.24369301217748257
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CTVA: 0.8363575765174541
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CSGP: 0.5982016523123462
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de COST: 0.6375995923785638
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CTRA: 0.6138700351606793
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CCI: 0.4439777144531532
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CSX: 0.738757902059526
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CMI: 0.7197164428800034
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de CVS: 0.4510633706882216
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DHI: 0.6637113261954674
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DHR: 0.8038656092990206
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DRI: 0.6560912642030576
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DVA: 0.8401000343612127
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DE: 0.7238474653066664
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DAL: 0.3840522308856803
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de XRAY: 0.43284524881679326
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DVN: 0.3787549751104191
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DXCM: 0.756891218673019
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FANG: 0.7892899180239807
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DLR: 0.7225669477187171
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DFS: 0.49918850380995994
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DISH: 0.04272361925620794
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DIS: 0.3410632794622754
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DG: 0.9232582456781743
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DLTR: 0.5512684469864846
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de D: 0.5613928815307686
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DPZ: 0.9002565089572905
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DOV: 0.4942688680489852
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DOW: 0.42707245331259003
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DTE: 0.6728699713523008
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DUK: 0.4917908453589043
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DD: 0.32788151303535745
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de DXC: 0.2418788146274734
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EMN: 0.4844608661796398
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ETN: 0.6890140452122958
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EBAY: 0.4565222383043971
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ECL: 0.6248030649241645
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EIX: 0.5004395226493306
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EW: 0.851719499836365
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EA: 0.4770167270621942
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ELV: 0.7603090253444693
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de LLY: 0.5864057912635491
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EMR: 0.4711648785585683
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ENPH: 0.9168481277330155
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ETR: 0.6588419238075993
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EOG: 0.6440410655091172
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EPAM: 0.9974599873483232
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EQT: 0.4741701046946641
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EFX: 0.6541323194539038
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EQIX: 0.41748729049896466
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EQR: 0.5116232605379166
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ESS: 0.6089320746532302
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EL: 0.5893151409445475
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ETSY: 0.6637922273159572
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de RE: 0.6641979829429795
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EVRG: 0.6234054400527324
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ES: 0.5685754971011117
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EXC: 0.5182474289756595
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EXPE: 0.41935298402419713
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EXPD: 0.5975460137079527
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de EXR: 0.8088797416118587
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de XOM: 0.4642313013164372
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FFIV: 0.4685300590144764
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FDS: 0.7015795507222796
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FICO: 0.7799875520419453
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FAST: 0.7086189470251658
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FRT: 0.5857413074263731
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FDX: 0.4786951830358194
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FITB: 0.2925147677072028
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FRC: 0.12306416384039719
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FSLR: 0.6035737561266934
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FE: 0.4547604219129143
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FIS: 0.461057572370053
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FISV: 0.6497306943049942
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FLT: 0.7916643904220655
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FMC: 0.6585128605642121
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de F: 0.2260565214469345
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FTNT: 1.0260298892363715
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FTV: 0.47223356896302887
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FOXA: 0.1237128864308549
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FOX: 0.018571193451338546
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de BEN: 0.3986428430684732
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de FCX: 0.5344771730654765
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GRMN: 0.6161501538955703
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de IT: 0.6213330022634763
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GEHC: 3.1242490377289838
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GEN: 0.45393456385391057
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GNRC: 0.7875333525588658
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GD: 0.6754023773474985
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GE: 0.07561731789630098
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GIS: 0.6795278015206525
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GM: 0.2591591308252827
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GPC: 0.688967034507592
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GILD: 0.7590424080707783
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GL: 0.6031957129813814
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GPN: 0.7200366839913391
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GS: 0.3963279462739566
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de HAL: 0.3504615339872994
# ...
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de SBUX: 0.67806283936062
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de STT: 0.33564081851690675
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de STLD: 0.7166234786297285
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de STE: 0.6939990551312729
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de SYK: 0.7063398041755705
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de SYF: 0.34578918923860175
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de SNPS: 0.614710252174042
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de SYY: 0.5250759248199799
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TMUS: 0.4449458499073282
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TROW: 0.5276292056886539
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TTWO: 0.5549946134270027
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TPR: 0.6379405725038609
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TRGP: 0.6248032319372173
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TGT: 0.4690905410621681
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TEL: 0.5204422046173712
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TDY: 0.6620666651054072
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TFX: 0.5773676799478566
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TER: 0.3263121838341583
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TSLA: 1.1166880581613428
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TXN: 0.37986583852768313
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TXT: 0.3609324944091204
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TMO: 0.792707760484231
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TJX: 0.7745781940237894
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TSCO: 0.9589871421166755
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TT: 0.6446513074911074
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TDG: 1.067118216742559
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TRV: 0.539385312881088
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TRMB: 0.5483470753834186
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TFC: 0.32600712503242757
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TYL: 0.7123605112669157
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de TSN: 0.4966333728275452
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de USB: 0.34856099362598186
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de UDR: 0.5789269911186617
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ULTA: 0.7470326981560249
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de UNP: 0.7835166117358878
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de UAL: 0.4097722047667538
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de UPS: 0.4905900525076523
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de URI: 0.6156811479757994
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de UNH: 0.8898187090629365
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de UHS: 0.5574173440177069
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VLO: 0.6672403580818829
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VTR: 0.7285124864275427
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VRSN: 0.3610429318113202
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VRSK: 0.8811827299919849
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VZ: 0.2506676779373454
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VRTX: 0.5549271888699002
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VFC: 0.48555513495197067
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VTRS: 0.1907622117141751
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VICI: 0.67506364244384
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de V: 0.915330033537722
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de VMC: 0.429034415836956
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WAB: 0.6179886895867517
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WBA: 0.27481163346188864
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WMT: 0.39147327921652725
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WBD: 0.3224179747870826
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WM: 0.743720943335417
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WAT: 0.4788178067116485
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WEC: 0.8421037791236657
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WFC: 0.36397888798686806
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WELL: 0.6706115626242463
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WST: 0.9290513825987591
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WDC: 0.48741202293296393
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WRK: 0.034178202184020685
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WY: 0.3417920402096301
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WHR: 0.3950730695772255
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WMB: 0.3897508566205994
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WTW: 0.569096441244741
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de GWW: 0.6786506576552518
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de WYNN: 0.6007785383595867
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de XEL: 0.562601317365654
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de XYL: 0.7450642032822602
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de YUM: 0.7942153107686537
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ZBRA: 0.568847849255971
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ZBH: 0.449761563422351
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ZION: 0.2585082686618034
# [*********************100%***********************]  1 of 1 completed
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Ratio Sharpe de ZTS: 0.9323418148470107

# %%
sorted_arr = sorted(symbols_ratio, key=lambda x: -x[1])

# %%
sorted_arr
# Out:
# [['GEHC', 3.1242490377289838],
#  ['CEG', 1.6092989766365635],
#  ['CARR', 1.5035184901053122],
#  ['MRNA', 1.1921532781974045],
#  ['CDW', 1.190247782303419],
#  ['AVGO', 1.183145584732412],
#  ['TSLA', 1.1166880581613428],
#  ['MA', 1.106219370989103],
#  ['PAYC', 1.096358546570109],
#  ['TDG', 1.067118216742559],
#  ['MNST', 1.0631763549685005],
#  ['FTNT', 1.0260298892363715],
#  ['ANET', 1.0213981617910144],
#  ['OTIS', 1.0084504469978535],
#  ['NOW', 0.9989552283343137],
#  ['EPAM', 0.9974599873483232],
#  ['SEDG', 0.9766223825833152],
#  ['AZO', 0.9763393772874998],
#  ['ABBV', 0.9720810638355456],
#  ['ODFL', 0.9621111513202569],
#  ['TSCO', 0.9589871421166755],
#  ['ORLY', 0.950236383037869],
#  ['KEYS', 0.9501141036777349],
#  ['GOOG', 0.934343387044552],
#  ['GOOGL', 0.9331580448651982],
#  ['ZTS', 0.9323418148470107],
#  ['CHD', 0.9309765006766137],
#  ['WST', 0.9290513825987591],
#  ['DG', 0.9232582456781743],
#  ['LW', 0.9226664539739817],
#  ['ENPH', 0.9168481277330155],
#  ['V', 0.915330033537722],
#  ['KDP', 0.9018389074873705],
#  ['AAPL', 0.900885591857037],
#  ['DPZ', 0.9002565089572905],
#  ['NFLX', 0.9002424642387598],
#  ['AME', 0.8952051020297421],
#  ['LMT', 0.8943439662843726],
#  ['AWK', 0.8942623806298532],
#  ['IDXX', 0.8901272821193411],
#  ['CZR', 0.8899723019706932],
#  ['UNH', 0.8898187090629365],
#  ['VRSK', 0.8811827299919849],
#  ['ANSS', 0.8798200003425104],
#  ['ABC', 0.8791206877959535],
#  ['WRB', 0.8723413711953772],
#  ['HCA', 0.8719936363996674],
#  ['MSCI', 0.8693803144928114],
#  ['CHTR', 0.8688318531051811],
#  ['ROL', 0.864321756593293],
#  ['NVR', 0.8637030297159836],
#  ['CMG', 0.8622887065358114],
#  ['POOL', 0.8590514443923203],
#  ['EW', 0.851719499836365],
#  ['NEE', 0.8502233181230173],
#  ['MO', 0.8463658805471058],
#  ['WEC', 0.8421037791236657],
#  ['DVA', 0.8401000343612127],
#  ['ACGL', 0.8389418735435132],
#  ['CTVA', 0.8363575765174541],
#  ['NOC', 0.8311644393215779],
#  ['MPWR', 0.8294541042738645],
#  ['SHW', 0.8291295213152936],
#  ['HII', 0.8231165045823217],
#  ['CME', 0.8198914873966726],
#  ['PGR', 0.81973998400797],
#  ['ATVI', 0.8174695642472207],
#  ['NXPI', 0.8095857991197007],
#  ['BRO', 0.8095364290521372],
#  ['EXR', 0.8088797416118587],
#  ['CRM', 0.8077159627832259],
#  ['MPC', 0.806967762087564],
#  ['DHR', 0.8038656092990206],
#  ['NVDA', 0.8027917879267369],
#  ['HUM', 0.7944470779305304],
#  ['YUM', 0.7942153107686537],
#  ['RSG', 0.7936075764470966],
#  ['IQV', 0.7934546961899316],
#  ['TMO', 0.792707760484231],
#  ['JBHT', 0.7922981781809638],
#  ['FLT', 0.7916643904220655],
#  ['FANG', 0.7892899180239807],
#  ['ISRG', 0.7884942924213376],
#  ['GNRC', 0.7875333525588658],
#  ['BALL', 0.7852987393141054],
#  ['MTD', 0.784558692586816],
#  ['CPRT', 0.7838382419386895],
#  ['UNP', 0.7835166117358878],
#  ['FICO', 0.7799875520419453],
#  ['HSY', 0.7781156798236909],
#  ['BLK', 0.7758394267194724],
#  ['TJX', 0.7745781940237894],
#  ['MKC', 0.7730030380926323],
#  ['ROST', 0.7728531760400318],
#  ['STZ', 0.7720654190230846],
#  ['LKQ', 0.7685423300468478],
#  ['BR', 0.7644148225319263],
#  ['AJG', 0.7643630097730607],
#  ['CF', 0.7638088951728546],
#  ['SO', 0.7636184846837409],
#  ['HRL', 0.7628686390856593],
#  ['PSA', 0.7625895328338883],
#  ['LIN', 0.7619951241077038],
#  ['ELV', 0.7603090253444693],
#  ['GILD', 0.7590424080707783],
#  ['ROP', 0.7570794020067511],
#  ['DXCM', 0.756891218673019],
#  ['ATO', 0.7543298753527615],
#  ['BIO', 0.7488123880938852],
#  ['NKE', 0.7483008595944562],
#  ['APTV', 0.7481436241232967],
#  ['IEX', 0.7480614126891039],
#  ['CNC', 0.7478202467844814],
#  ['ULTA', 0.7470326981560249],
#  ['IR', 0.7459098511133403],
#  ['ACN', 0.7458932151098515],
#  ['XYL', 0.7450642032822602],
#  ['WM', 0.743720943335417],
#  ['HSIC', 0.7433125942800772],
#  ['LYB', 0.7396909091240523],
#  ['CSX', 0.738757902059526],
#  ['SRE', 0.7345402939880564],
#  ['MCO', 0.7315016636338626],
#  ['PODD', 0.7287009172111024],
#  ['VTR', 0.7285124864275427],
#  ['AOS', 0.728366755725936],
#  ['SJM', 0.7242190779097583],
#  ['DE', 0.7238474653066664],
#  ['DLR', 0.7225669477187171],
#  ['GPN', 0.7200366839913391],
#  ['CMI', 0.7197164428800034],
#  ['MKTX', 0.7183479490340815],
#  ['STLD', 0.7166234786297285],
#  ['TYL', 0.7123605112669157],
#  ['FAST', 0.7086189470251658],
#  ['SYK', 0.7063398041755705],
#  ['OKE', 0.7044213155812432],
#  ['FDS', 0.7015795507222796],
#  ['ROK', 0.7010910580954564],
#  ['O', 0.6960738161020134],
#  ['LH', 0.6957349716243754],
#  ['SPGI', 0.6952725041852545],
#  ['STE', 0.6939990551312729],
#  ['PKG', 0.6934614861623406],
#  ['HOLX', 0.6929866110290503],
#  ['APH', 0.6925874333799948],
#  ['CBOE', 0.6894299046225119],
#  ['ETN', 0.6890140452122958],
#  ['GPC', 0.688967034507592],
#  ['RMD', 0.6887115833663745],
#  ['ALB', 0.6851537686905191],
#  ['MCD', 0.6823720485843627],
#  ['BDX', 0.6809464567399036],
#  ['MAA', 0.6799467859900346],
#  ['GIS', 0.6795278015206525],
#  ['NSC', 0.6794894298526091],
#  ['GWW', 0.6786506576552518],
#  ['MCK', 0.6783411440369456],
#  ['SBUX', 0.67806283936062],
#  ['META', 0.6777793759533105],
#  ['ICE', 0.6763940843194173],
#  ['ED', 0.6760372125203933],
#  ['GD', 0.6754023773474985],
#  ['MOH', 0.675276208630437],
#  ['VICI', 0.67506364244384],
#  ['APD', 0.6739708930789786],
#  ['DTE', 0.6728699713523008],
#  ['CDAY', 0.6728659910643588],
#  ['PCAR', 0.6716947241517066],
#  ['WELL', 0.6706115626242463],
#  ['COO', 0.6677847284093564],
#  ['VLO', 0.6672403580818829],
#  ['DGX', 0.665905924700293],
#  ['RE', 0.6641979829429795],
#  ['ETSY', 0.6637922273159572],
#  ['DHI', 0.6637113261954674],
#  ['PG', 0.6630189989212346],
#  ['TDY', 0.6620666651054072],
#  ['ETR', 0.6588419238075993],
#  ['FMC', 0.6585128605642121],
#  ['NDSN', 0.6583673034394453],
#  ['DRI', 0.6560912642030576],
#  ['EFX', 0.6541323194539038],
#  ['LHX', 0.6520384140428499],
#  ['HLT', 0.6517812793791052],
#  ['CAT', 0.6512491833277264],
#  ['CTSH', 0.6508117586423982],
#  ['PEP', 0.6507843662798866],
#  ['SNA', 0.6498657410128574],
#  ['FISV', 0.6497306943049942],
#  ['KMX', 0.649070923475588],
#  ['TT', 0.6446513074911074],
#  ['EOG', 0.6440410655091172],
#  ['CTLT', 0.643014045980624],
#  ['REGN', 0.6401958552592553],
#  ['ITW', 0.6396469117490593],
#  ['PSX', 0.6386886501583783],
#  ['AMZN', 0.6383993338303948],
#  ['CHRW', 0.6382705926150188],
#  ['TPR', 0.6379405725038609],
#  ['COST', 0.6375995923785638],
#  ['AON', 0.6342298991647901],
#  ['AMP', 0.6338950795524934],
#  ['PH', 0.6323684056006084],
#  ['JNJ', 0.632361110801908],
#  ['NUE', 0.6298177274125961],
#  ['CTAS', 0.6296779620682977],
#  ['NI', 0.6291702561338645],
#  ['PXD', 0.6282650195073358],
#  ['LOW', 0.6262203126413901],
#  ['TRGP', 0.6248032319372173],
#  ['ECL', 0.6248030649241645],
#  ['EVRG', 0.6234054400527324],
#  ['IT', 0.6213330022634763],
#  ['WAB', 0.6179886895867517],
#  ['RJF', 0.6176519916289789],
#  ['GRMN', 0.6161501538955703],
#  ['URI', 0.6156811479757994],
#  ['LNT', 0.6155020917773915],
#  ['SNPS', 0.614710252174042],
#  ['CTRA', 0.6138700351606793],
#  ['ABT', 0.610631153380958],
#  ['INTU', 0.6105850872056714],
#  ['ESS', 0.6089320746532302],
#  ['PEG', 0.6080710461854377],
#  ['ALGN', 0.607418089670505],
#  ['ADM', 0.6053923639099448],
#  ['FSLR', 0.6035737561266934],
#  ['GL', 0.6031957129813814],
#  ['CB', 0.6023014665468963],
#  ['WYNN', 0.6007785383595867],
#  ['ADSK', 0.6000179554630649],
#  ['CSGP', 0.5982016523123462],
#  ['EXPD', 0.5975460137079527],
#  ['HWM', 0.5961953852254364],
#  ['IRM', 0.5927203820314237],
#  ['NDAQ', 0.5913762485185593],
#  ['J', 0.5906451021201375],
#  ['EL', 0.5893151409445475],
#  ['LLY', 0.5864057912635491],
#  ['CLX', 0.5861762055083674],
#  ['FRT', 0.5857413074263731],
#  ['CBRE', 0.5856567897799775],
#  ['AEE', 0.585213375180799],
#  ['UDR', 0.5789269911186617],
#  ['TFX', 0.5773676799478566],
#  ['ADP', 0.5753996525192046],
#  ['MAR', 0.5748852857171419],
#  ['CE', 0.5720301639186973],
#  ['WTW', 0.569096441244741],
#  ['ZBRA', 0.568847849255971],
#  ['ES', 0.5685754971011117],
#  ['JKHY', 0.5684914342820292],
#  ['PM', 0.5666436775108079],
#  ['SPG', 0.5665163246566651],
#  ['PNW', 0.5662869346680574],
#  ['ADBE', 0.565618105776521],
#  ['STX', 0.5652888079287316],
#  ['PLD', 0.5635404472206238],
#  ['BWA', 0.563158798459182],
#  ['AVB', 0.5631011069422401],
#  ['CPT', 0.563093668445767],
#  ['XEL', 0.562601317365654],
#  ['LRCX', 0.5614037611376578],
#  ['D', 0.5613928815307686],
#  ['AEP', 0.5611818651917323],
#  ['COP', 0.558251791449026],
#  ['UHS', 0.5574173440177069],
#  ['AAP', 0.5557978370059732],
#  ['TTWO', 0.5549946134270027],
#  ['VRTX', 0.5549271888699002],
#  ['LEN', 0.5544633640285355],
#  ['PHM', 0.5519620061754076],
#  ['ILMN', 0.5517796481815704],
#  ['DLTR', 0.5512684469864846],
#  ['OXY', 0.5511561973352076],
#  ['TECH', 0.5488838186434367],
#  ['TRMB', 0.5483470753834186],
#  ['MSFT', 0.5478469347374109],
#  ['CI', 0.5461941005562159],
#  ['ALLE', 0.5444978130514518],
#  ['BG', 0.5418489079536306],
#  ['MDLZ', 0.5406408691312332],
#  ['CDNS', 0.5402364093642728],
#  ['PPL', 0.540203685114059],
#  ['TRV', 0.539385312881088],
#  ['LYV', 0.5372406896622427],
#  ['AIZ', 0.5371591572118714],
#  ['MLM', 0.5357344572944299],
#  ['PPG', 0.535246956602159],
#  ['FCX', 0.5344771730654765],
#  ['RTX', 0.5323247095985955],
#  ['CVX', 0.5303777228473281],
#  ['MCHP', 0.5285731234699385],
#  ['TROW', 0.5276292056886539],
#  ['ARE', 0.5267489596937751],
#  ['SYY', 0.5250759248199799],
#  ['TEL', 0.5204422046173712],
#  ['EXC', 0.5182474289756595],
#  ['CRL', 0.5178742646621143],
#  ['REG', 0.5138582444568535],
#  ['BKNG', 0.5135813221103775],
#  ['EQR', 0.5116232605379166],
#  ['AFL', 0.5082314516762451],
#  ['BA', 0.5074847379459321],
#  ['L', 0.5073907895356187],
#  ['KLAC', 0.5059896839403443],
#  ['ALL', 0.5059867013166454],
#  ['BIIB', 0.505196485338899],
#  ['LDOS', 0.5036718518887492],
#  ['K', 0.5024021361232524],
#  ['INVH', 0.5011174989577699],
#  ['EIX', 0.5004395226493306],
#  ['KR', 0.5002035664096913],
#  ['DFS', 0.49918850380995994],
#  ['HES', 0.497420270628458],
#  ['TSN', 0.4966333728275452],
#  ['SBAC', 0.49587282734401344],
#  ['CMS', 0.4954717383282274],
#  ['DOV', 0.4942688680489852],
#  ['CAG', 0.49203458772963965],
#  ['DUK', 0.4917908453589043],
#  ['KMB', 0.49142775583322856],
#  ['UPS', 0.4905900525076523],
#  ['CINF', 0.48985596634202666],
#  ['PYPL', 0.48832757286597916],
#  ['WDC', 0.48741202293296393],
#  ['HPE', 0.4859350341538675],
#  ['VFC', 0.48555513495197067],
#  ['EMN', 0.4844608661796398],
#  ['HD', 0.48396228335065894],
#  ['PEAK', 0.48361728991829384],
#  ['MTCH', 0.48178936038847003],
#  ['KO', 0.47954140282000246],
#  ['WAT', 0.4788178067116485],
#  ['FDX', 0.4786951830358194],
#  ['RL', 0.47866617225335645],
#  ['EA', 0.4770167270621942],
#  ['EQT', 0.4741701046946641],
#  ['PFG', 0.47398528416008195],
#  ['FTV', 0.47223356896302887],
#  ['EMR', 0.4711648785585683],
#  ['PNR', 0.4693454740829233],
#  ['TGT', 0.4690905410621681],
#  ['MET', 0.46905512746293854],
#  ['FFIV', 0.4685300590144764],
#  ['PAYX', 0.4684781216101058],
#  ['HON', 0.46825792411243883],
#  ['XOM', 0.4642313013164372],
#  ['ALK', 0.46408179591736576],
#  ['BBWI', 0.46150945592029724],
#  ['FIS', 0.461057572370053],
#  ['MMC', 0.4569190921073063],
#  ['EBAY', 0.4565222383043971],
#  ['AMD', 0.4553092597521598],
#  ['FE', 0.4547604219129143],
#  ['PWR', 0.45457597322956983],
#  ['GEN', 0.45393456385391057],
#  ['ON', 0.4526615378982627],
#  ['CVS', 0.4510633706882216],
#  ['ZBH', 0.449761563422351],
#  ['PRU', 0.448356651932775],
#  ['AMGN', 0.44672484565224674],
#  ['MRO', 0.446310627269005],
#  ['AMT', 0.4455538918213677],
#  ['TMUS', 0.4449458499073282],
#  ['CCI', 0.4439777144531532],
#  ['NRG', 0.44222417404036507],
#  ['AVY', 0.4413035234100938],
#  ['HAS', 0.4409801970615098],
#  ['AMCR', 0.44092648942889195],
#  ['PTC', 0.437164725181285],
#  ['PNC', 0.43641228849470753],
#  ['SWKS', 0.4362678269324885],
#  ['CL', 0.43567016282411425],
#  ['MGM', 0.4349659137096214],
#  ['PKI', 0.4330637353571071],
#  ['XRAY', 0.43284524881679326],
#  ['SWK', 0.4326856278270346],
#  ['VMC', 0.429034415836956],
#  ['CAH', 0.4288492007585544],
#  ['DOW', 0.42707245331259003],
#  ['MOS', 0.4224870196451805],
#  ['AXP', 0.42121246740479007],
#  ['BSX', 0.41943248214558576],
#  ['EXPE', 0.41935298402419713],
#  ['MMM', 0.41921716831606903],
#  ['MMM', 0.4192171299121675],
#  ['RCL', 0.41770855070936047],
#  ['EQIX', 0.41748729049896466],
#  ['KIM', 0.4153465444210231],
#  ['MTB', 0.4147929504085272],
#  ['CFG', 0.41308650375621186],
#  ['RHI', 0.41273985481412384],
#  ['IFF', 0.4105003256614151],
#  ['UAL', 0.4097722047667538],
#  ['BXP', 0.40921908436417276],
#  ['MHK', 0.40584090221937114],
#  ['LVS', 0.40331740074255806],
#  ['CNP', 0.40305161868284756],
#  ['JPM', 0.40005104112813217],
#  ['MRK', 0.39941150692435623],
#  ['MAS', 0.3992028161823066],
#  ['BEN', 0.3986428430684732],
#  ['INCY', 0.39785728471584747],
#  ['ADI', 0.3965857110084042],
#  ['GS', 0.3963279462739566],
#  ['WHR', 0.3950730695772255],
#  ['AMAT', 0.3941494892855066],
#  ['BBY', 0.3928953617560723],
#  ['WMT', 0.39147327921652725],
#  ['WMB', 0.3897508566205994],
#  ['HST', 0.3875281242503372],
#  ['CPB', 0.3858966394760886],
#  ['DAL', 0.3840522308856803],
#  ['BAX', 0.3827257512762091],
#  ['TXN', 0.37986583852768313],
#  ['DVN', 0.3787549751104191],
#  ['CMCSA', 0.3712529247107006],
#  ['HIG', 0.3700393596008912],
#  ['COF', 0.3676463152730123],
#  ['TAP', 0.36526949132307784],
#  ['WFC', 0.36397888798686806],
#  ['APA', 0.36393252223352074],
#  ['NEM', 0.3637543561094389],
#  ['VRSN', 0.3610429318113202],
#  ['TXT', 0.3609324944091204],
#  ['AAL', 0.3575978887871464],
#  ['QRVO', 0.3523996886166974],
#  ['QCOM', 0.35138326534123454],
#  ['OMC', 0.35108169168994807],
#  ['HAL', 0.3504615339872994],
#  ['USB', 0.34856099362598186],
#  ['ORCL', 0.347001167681666],
#  ['SYF', 0.34578918923860175],
#  ['RF', 0.3435012786574712],
#  ['WY', 0.3417920402096301],
#  ['DIS', 0.3410632794622754],
#  ['STT', 0.33564081851690675],
#  ['DD', 0.32788151303535745],
#  ['MS', 0.3277655361034627],
#  ['LUV', 0.326999280335514],
#  ['TER', 0.3263121838341583],
#  ['TFC', 0.32600712503242757],
#  ['MSI', 0.32545005521283465],
#  ['BMY', 0.3246436806298841],
#  ['A', 0.323879630435993],
#  ['AKAM', 0.323363887420004],
#  ['WBD', 0.3224179747870826],
#  ['NTAP', 0.3215160019899373],
#  ['T', 0.32097612580883444],
#  ['BAC', 0.31981856822798715],
#  ['MU', 0.3196289009625174],
#  ['LNC', 0.31655911023574634],
#  ['CMA', 0.3132164899905038],
#  ['SCHW', 0.31161003365253],
#  ['SEE', 0.30944179361376223],
#  ['BKR', 0.30717130620381955],
#  ['PCG', 0.3043794195465142],
#  ['HBAN', 0.30427785664686136],
#  ['PFE', 0.3042043773485165],
#  ['HPQ', 0.29338407048778037],
#  ['SLB', 0.2930876326198472],
#  ['FITB', 0.2925147677072028],
#  ['KEY', 0.2924700697486183],
#  ['IP', 0.2828220723511366],
#  ['NTRS', 0.2814610325885682],
#  ['PARA', 0.2772483367996242],
#  ['MDT', 0.27636725649157545],
#  ['WBA', 0.27481163346188864],
#  ['AES', 0.2718762542197833],
#  ['IVZ', 0.2640878390339881],
#  ['BK', 0.2629114194850918],
#  ['GM', 0.2591591308252827],
#  ['IBM', 0.25859813418728067],
#  ['ZION', 0.2585082686618034],
#  ['VZ', 0.2506676779373454],
#  ['GLW', 0.24369301217748257],
#  ['DXC', 0.2418788146274734],
#  ['IPG', 0.23766970633962153],
#  ['JCI', 0.23655507659300903],
#  ['NWS', 0.22827202897125284],
#  ['F', 0.2260565214469345],
#  ['NWSA', 0.21926209265934218],
#  ['CCL', 0.20606196040696742],
#  ['CSCO', 0.19809081723504468],
#  ['VTRS', 0.1907622117141751],
#  ['JNPR', 0.18931387072197298],
#  ['NWL', 0.18799403769215556],
#  ['NCLH', 0.18658886825212742],
#  ['INTC', 0.16642328814058355],
#  ['KMI', 0.1432736427573971],
#  ['FOXA', 0.1237128864308549],
#  ['FRC', 0.12306416384039719],
#  ['GE', 0.07561731789630098],
#  ['C', 0.07286963786341444],
#  ['AIG', 0.0514783387055601],
#  ['DISH', 0.04272361925620794],
#  ['WRK', 0.034178202184020685],
#  ['FOX', 0.018571193451338546],
#  ['KHC', -0.026995931181467356],
#  ['OGN', -0.3967366461978714]]

# %%
""" with open('ratio_sharpe.csv', mode='w', newline='') as f:
    writer = csv.writer(f)
    for row in symbols_ratio:
        writer.writerow(row) """
